# %% [markdown]
# ## ZBTCNN RL
# **Reinforcement Learning Trading Bot**
#
# Decides between buy/sell/stand given past and future price input

# %%
import os
import sys
import random
import time
from collections import deque
import pandas as pd
import numpy as np
from sklearn import preprocessing
from enum import Enum
import stable_baselines3
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.a2c.a2c import A2C
import gym
from gym import error, spaces, utils
from gym.utils import seeding
import json
import joblib
import matplotlib.pyplot as plt
import os

# CD to top level git directory
if ".git" not in os.listdir("."):
    os.chdir("../../")

# %%
# Data parameters
SEQ_LEN = 48 #hours
FUTURE_PERIOD_PREDICT = 1 #hours

# Hyperparameter Optimizer parameters
# MAX_TRIALS = 40 # 10t x 20e ~ 4h

# Model parameters
# EPOCHS = 20
# BATCH_SIZE = 16
NAME = f"RL-SB3-Myenv-{int(time.time())}"

# %%
## Import data
# DATA MUST BE FORMATTED USING CSV_FORMATTER.IPYNB

csv_file = "data/formatted/BTCUSDT-1h-data.csv"

data = pd.read_csv(csv_file, skiprows=[0], names=["timestamp", "open", "high", "low", "close", "volume", "rsi", "ema"])

data.set_index("timestamp", inplace=True)

data.head()
# Out:
#                open     high      low    close     volume        rsi  \
# timestamp
# 1503064800  4304.15  4371.52  4296.04  4356.31  51.563675  52.623958
# 1503068400  4356.31  4357.37  4302.72  4340.31  24.093449  51.678528
# 1503072000  4320.52  4340.31  4287.79  4331.71  15.118957  51.167386
# 1503075600  4302.97  4318.16  4221.05  4293.09  46.533767  48.919621
# 1503079200  4293.09  4293.09  4193.70  4259.40  74.368943  47.054235
#
#                     ema
# timestamp
# 1503064800  4327.151560
# 1503068400  4327.804777
# 1503072000  4327.995329
# 1503075600  4326.319858
# 1503079200  4323.157459

# %%
## Add min max bounds to data

price_max = 80000.0
volume_max = 60000.0
rsi_max = 100.0

price_min = 2000.0
volume_min = 0.0
rsi_min = 0.0

max_df = pd.DataFrame()

max_df["timestamp"] = []

for col in data.columns:
    max_df[col] = []

max_df = max_df.append({"timestamp": "1",
                "open": price_max,
                "high": price_max,
                "low": price_max,
                "close": price_max,
                "volume": volume_max,
                "rsi": rsi_max,
                "ema": price_max,
                "target": price_max}, ignore_index=True)

max_df = max_df.append({"timestamp": "0",
                "open": price_min,
                "high": price_min,
                "low": price_min,
                "close": price_min,
                "volume": volume_min,
                "rsi": rsi_min,
                "ema": price_min,
                "target": price_min}, ignore_index=True)

max_df.set_index("timestamp", inplace=True)

max_df.head()
# Out:
# /tmp/ipykernel_2446/614491842.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   max_df = max_df.append({"timestamp": "1",
# /tmp/ipykernel_2446/614491842.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   max_df = max_df.append({"timestamp": "0",
#               open     high      low    close   volume    rsi      ema  \
# timestamp
# 1          80000.0  80000.0  80000.0  80000.0  60000.0  100.0  80000.0
# 0           2000.0   2000.0   2000.0   2000.0      0.0    0.0   2000.0
#
#             target
# timestamp
# 1          80000.0
# 0           2000.0

# %%
## Formatting data and Scaler Initialization

# def classify(current, future):
#     return float((future - current) / current)


data["target"] = data["close"].shift(-FUTURE_PERIOD_PREDICT)

# # Cut off NaNs
# # data = data[:-FUTURE_PERIOD_PREDICT]
data.replace([np.inf, -np.inf], np.nan, inplace=True)
data.dropna(inplace=True)

# data["target"] = list(map(classify, data["close"], data["future"]))
# # data[["close", "future", "target"]].tail()
# data = data.drop("future", 1)

# Fit scalers
price_scaler = preprocessing.MinMaxScaler(feature_range=(-1, 1))
volume_scaler = preprocessing.MinMaxScaler(feature_range=(-1, 1))
rsi_scaler = preprocessing.MinMaxScaler(feature_range=(-1, 1))

data = data.append(max_df)

price_scaler.fit(np.array(data["close"]).reshape(-1, 1))
volume_scaler.fit(np.array(data["volume"]).reshape(-1, 1))
rsi_scaler.fit(np.array(data["rsi"]).reshape(-1, 1))

#Dump scalers
try:
    os.mkdir(f"scalers/{NAME}")
except:
    pass

joblib.dump(price_scaler, f"scalers/{NAME}/price_scaler")
joblib.dump(volume_scaler, f"scalers/{NAME}/volume_scaler")
joblib.dump(rsi_scaler, f"scalers/{NAME}/rsi_scaler")

# Remove min max boundary values
data = data[:-2]


# Split dataset # Dont split here; do split after shuffle
# last_5_pct = int(len(data) * .95)

# train_data = data[:last_5_pct]
# validation_data = data[last_5_pct:]

# print(f"{len(train_data)} :: {len(validation_data)}")

data.head()
# Out:
# /tmp/ipykernel_2446/256690262.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(max_df)
#                open     high      low    close     volume        rsi  \
# timestamp
# 1503064800  4304.15  4371.52  4296.04  4356.31  51.563675  52.623958
# 1503068400  4356.31  4357.37  4302.72  4340.31  24.093449  51.678528
# 1503072000  4320.52  4340.31  4287.79  4331.71  15.118957  51.167386
# 1503075600  4302.97  4318.16  4221.05  4293.09  46.533767  48.919621
# 1503079200  4293.09  4293.09  4193.70  4259.40  74.368943  47.054235
#
#                     ema   target
# timestamp
# 1503064800  4327.151560  4340.31
# 1503068400  4327.804777  4331.71
# 1503072000  4327.995329  4293.09
# 1503075600  4326.319858  4259.40
# 1503079200  4323.157459  4236.89

# %%
## Preprocess Data

def preprocess_df_p1(df_p):

    df = pd.DataFrame()
    for col in df_p.columns:
        df[col] = df_p[col]

    for col in df.columns:
        scaler = None
        if col in ["open", "high", "low", "close", "ema", "target"]:
            scaler = price_scaler
        elif col == "volume":
            scaler = volume_scaler
        elif col == "rsi":
            scaler = rsi_scaler
        else:
            raise Exception("Column not recognized and scaler cannot be determined")

        df.replace([np.inf, -np.inf], np.nan, inplace=True)
        df.dropna(inplace=True)
        df[col] = scaler.transform(np.array(df[col]).reshape(-1, 1))

        
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    df.dropna(inplace=True)

    sequential_data = []
    prev_periods = deque(maxlen=SEQ_LEN)

    for i in df.values:
        prev_periods.append([n for n in i[:-1]])
        if len(prev_periods) == SEQ_LEN:
            sequential_data.append([np.array(prev_periods), i[-1]])

    return sequential_data
    # random.shuffle(sequential_data)

def preprocess_df_p2(seq_data):

    # Balance buys and sells
    buys = []
    sells = []

    for seq, target in seq_data:

        if target < seq[-1][3]: #compares to close column
            sells.append([seq, target])
        elif target > seq[-1][3]:
            buys.append([seq, target])

    lower = min(len(buys), len(sells))

    buys = buys[:lower]
    sells = sells[:lower]

    local_seq_data = buys + sells

    random.shuffle(local_seq_data)

    X = [d[0] for d in local_seq_data]
    Y = [d[1] for d in local_seq_data]

    return np.array(X), np.array(Y)
    

# train_x, train_y = preprocess_df(train_data)
# validation_x, validation_y = preprocess_df(validation_data)

# Preprocess and split data here
seq_data_full = preprocess_df_p1(data)

last_5_pct = int(len(seq_data_full) * .95)

seq_data_train = seq_data_full[:last_5_pct]
seq_data_val = seq_data_full[last_5_pct:]

train_x, train_y = preprocess_df_p2(seq_data_train)
validation_x, validation_y = preprocess_df_p2(seq_data_val)

# %%
## Dataset metrics

close_target_list = list(zip([x[-1][3] for x in list(train_x)], list(train_y)))

train_sell_counter = len([x for x in close_target_list if x[0] > x[1]])
train_buy_counter = len([x for x in close_target_list if x[0] < x[1]])

close_target_list = list(zip([x[-1][3] for x in list(validation_x)], list(validation_y)))

val_sell_counter = len([x for x in close_target_list if x[0] > x[1]])
val_buy_counter = len([x for x in close_target_list if x[0] < x[1]])

print(f"Train : Validation == {len(train_x)} : {len(validation_x)}")
print(f"Train\t\tBuys : Sells == {train_buy_counter} : {train_sell_counter}")
print(f"Validation\tBuys : Sells == {val_buy_counter} : {val_sell_counter}")
# Out:
# Train : Validation == 35626 : 1882
# Train		Buys : Sells == 17813 : 17813
# Validation	Buys : Sells == 941 : 941

# %%
action_str_list = ["BUY", "SELL", "HOLD"]


class TradingEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    INITIAL_BAL = 10000

    def __init__(self, data):
        # Env Dataset
        # data fmt = (train_x, train_y)
        self.data = data
        self.data_index = 0

        # Gym Vars

        # These are raw price ranges but train_x is scaled
        # observation_high = np.array([max_df.loc["1"].to_numpy()[:-1] for _ in range(SEQ_LEN)])
        # observation_low = np.array([max_df.loc["0"].to_numpy()[:-1] for _ in range(SEQ_LEN)])

        observation_high = np.array([np.array([1,1,1,1,1,1,1], dtype=np.float64) for _ in range(SEQ_LEN)], dtype=np.float64)
        observation_low = np.array([np.array([1,1,1,1,1,1,1], dtype=np.float64)*-1 for _ in range(SEQ_LEN)], dtype=np.float64)

        self.action_space = spaces.Discrete(3)
        self.observation_space = spaces.Box(low=observation_low, high=observation_high, dtype=np.float64)

        self.score = 0.0 #optional

        # Trading Vars
        self.balance = self.INITIAL_BAL
        self.position = 0 #long=1;flat=0
        self.last_sharpe = 0
        self.profits = []
        self.total_profit = 0

    def seed(self):
        pass

    def _calc_reward(self, profits):
        sharpe = np.float64(np.sum(np.array(profits)) / (np.std(np.array(profits)) + .0001))
        ret = sharpe - self.last_sharpe
        if ret != np.inf and ret != -np.inf and ret != np.nan:
            self.last_sharpe = sharpe
            return ret
        else:
            return 0

    def step(self, action):
        # Make sure action is within bounds
        assert self.action_space.contains(action)

        done = False
        reward = 0

        if self.data_index == len(self.data[0]) - 2:
            done = True

        state = self.data[0][self.data_index]

        # Calculate Reward and Balance
        curr_price = price_scaler.inverse_transform(np.array([self.data[0][self.data_index][-1][3]]).reshape(-1,1)).tolist()[0][0]
        next_price = price_scaler.inverse_transform(np.array([self.data[1][self.data_index]]).reshape(-1,1)).tolist()[0][0]

        old_balance = self.balance
        if action == action_str_list.index("BUY"):
            self.balance *= next_price / curr_price
            self.position = 1 #long
        elif action == action_str_list.index("SELL"):
            self.position = 0 #flat
            pass # balance is unchanged
        elif action == action_str_list.index("HOLD"):
            # continue with previous position
            if self.position == 1:
                self.balance *= next_price / curr_price
            elif self.position == 0:
                pass # balance is unchanged


        # Reward is difference in balances
        profit = self.balance - old_balance
        self.profits.append(profit)
        reward = self._calc_reward(self.profits)
        self.score += profit

        # Record step results in info
        info =  {
                    "index": self.data_index,
                    "action": action_str_list[action],
                    "profit": profit,
                    "reward": reward,
                    "score": self.score
                }

        # Increment data index and set state to next step data
        self.data_index += 1
        state = self.data[0][self.data_index]

        return state, reward, done, info

    def render(self, mode='human'):
        pass

    def reset(self):
        self.data_index = 0
        self.score = 0.0
        self.balance = self.INITIAL_BAL
        self.position = 0 #long=1;flat=0
        self.last_sharpe = 0
        self.profits = []
        self.total_profit = 0
        return self.data[0][self.data_index]

# %%
# Set bounds

train_bounds = (10000, 25000)
test_bounds = (25000, 38000)

# %%
# Auto env generation

train_env_factory = lambda: TradingEnv((train_x[train_bounds[0]:train_bounds[1]], train_y[train_bounds[0]:train_bounds[1]]))
test_env_factory = lambda: TradingEnv((train_x[test_bounds[0]:test_bounds[1]], train_y[test_bounds[0]:test_bounds[1]]))


train_env = DummyVecEnv([train_env_factory])
test_env = DummyVecEnv([test_env_factory])

# %%
# Make model

model = A2C("MlpPolicy", train_env, verbose=1, tensorboard_log=f"./logs/{NAME}")
# Out:
# Using cuda device

# %%
# Train model

model = model.learn(total_timesteps=300000, eval_env=test_env)
# Out:
# Logging to ./logs/RL-SB3-Myenv-1647152968/A2C_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -0.184   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0245  |
# |    value_loss         | 0.133    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 295      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.00588  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.839    |
# |    value_loss         | 1.19     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.945   |
# |    explained_variance | -0.00913 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.417   |
# |    value_loss         | 0.92     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.952   |
# |    explained_variance | 0.0194   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.31     |
# |    value_loss         | 1.4      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 500      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.893   |
# |    explained_variance | -10.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.122    |
# |    value_loss         | 0.095    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 600      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.828   |
# |    explained_variance | -1.43    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.606    |
# |    value_loss         | 1.64     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 700      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.696   |
# |    explained_variance | -5.39    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.15     |
# |    value_loss         | 0.0369   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 800      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.89    |
# |    explained_variance | -4.12    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.601    |
# |    value_loss         | 0.266    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 900      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.867   |
# |    explained_variance | -0.328   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -1.96    |
# |    value_loss         | 1.63     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 348      |
# |    iterations         | 1000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.73    |
# |    explained_variance | -2.2     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0502   |
# |    value_loss         | 0.00297  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 346      |
# |    iterations         | 1100     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.256   |
# |    explained_variance | -0.253   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.000928 |
# |    value_loss         | 0.000327 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 340      |
# |    iterations         | 1200     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.179   |
# |    explained_variance | -19.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.000474 |
# |    value_loss         | 0.000249 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 1300     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.456   |
# |    explained_variance | -0.102   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.0316   |
# |    value_loss         | 0.0574   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 336      |
# |    iterations         | 1400     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.16    |
# |    explained_variance | -171     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.000496 |
# |    value_loss         | 0.000844 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 336       |
# |    iterations         | 1500      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.111    |
# |    explained_variance | -23       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -3.01e-05 |
# |    value_loss         | 3.81e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 335       |
# |    iterations         | 1600      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.117    |
# |    explained_variance | -108      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -9.82e-05 |
# |    value_loss         | 3.15e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 335       |
# |    iterations         | 1700      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.0897   |
# |    explained_variance | -75.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -0.000661 |
# |    value_loss         | 0.00245   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 1800     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.13    |
# |    explained_variance | -878     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.000442 |
# |    value_loss         | 0.000492 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 332       |
# |    iterations         | 1900      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.0678   |
# |    explained_variance | -3.28     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -1.79e-05 |
# |    value_loss         | 4.11e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 2000      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.22     |
# |    explained_variance | -0.264    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -9.92e-05 |
# |    value_loss         | 5.81e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 329       |
# |    iterations         | 2100      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.166    |
# |    explained_variance | -0.281    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.000869 |
# |    value_loss         | 3.04e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 2200      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.192    |
# |    explained_variance | -317      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -2.86e-05 |
# |    value_loss         | 2.46e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 2300     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.37    |
# |    explained_variance | -0.242   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.000242 |
# |    value_loss         | 4.8e-06  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 323      |
# |    iterations         | 2400     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.886   |
# |    explained_variance | -0.219   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.165    |
# |    value_loss         | 0.19     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 2500     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.735   |
# |    explained_variance | -0.00581 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0113   |
# |    value_loss         | 0.00723  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 319       |
# |    iterations         | 2600      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.542    |
# |    explained_variance | -0.000317 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 0.00461   |
# |    value_loss         | 0.253     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 2700     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.585   |
# |    explained_variance | 0.0396   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.0496   |
# |    value_loss         | 0.057    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 2800     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.465   |
# |    explained_variance | 0.0331   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0298  |
# |    value_loss         | 0.526    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 313      |
# |    iterations         | 2900     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.456   |
# |    explained_variance | -0.117   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.252    |
# |    value_loss         | 2.3      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 311      |
# |    iterations         | 3000     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.394   |
# |    explained_variance | 0.0259   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.195    |
# |    value_loss         | 0.776    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 3100     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.368   |
# |    explained_variance | -0.018   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0547  |
# |    value_loss         | 0.33     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 3200     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.152   |
# |    explained_variance | -0.00211 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0198   |
# |    value_loss         | 0.967    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 320      |
# |    iterations         | 3300     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.18    |
# |    explained_variance | -0.00967 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0463  |
# |    value_loss         | 1.72     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 322      |
# |    iterations         | 3400     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | 0.00941  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.169    |
# |    value_loss         | 0.891    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 3500     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.611   |
# |    explained_variance | -0.133   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.43     |
# |    value_loss         | 0.222    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 3600     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.601   |
# |    explained_variance | 0.0535   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.303    |
# |    value_loss         | 0.256    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 327      |
# |    iterations         | 3700     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.499   |
# |    explained_variance | 0.138    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0764   |
# |    value_loss         | 0.24     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 3800     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.605   |
# |    explained_variance | -0.00408 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.583    |
# |    value_loss         | 26.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 329      |
# |    iterations         | 3900     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | 0.051    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -1.92    |
# |    value_loss         | 4.51     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 4000     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.759   |
# |    explained_variance | 0.0316   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0188  |
# |    value_loss         | 0.000625 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 4100     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.833   |
# |    explained_variance | 0.000381 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.529   |
# |    value_loss         | 0.638    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 4200     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.516   |
# |    explained_variance | -0.0667  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 1.06     |
# |    value_loss         | 4.37     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 4300     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.341   |
# |    explained_variance | 0.178    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.142    |
# |    value_loss         | 0.0435   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 4400     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.196   |
# |    explained_variance | -0.0105  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.158   |
# |    value_loss         | 14       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 4500     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.173   |
# |    explained_variance | -0.0204  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0498  |
# |    value_loss         | 1.72     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 4600     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.139   |
# |    explained_variance | -0.345   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.00612 |
# |    value_loss         | 0.0518   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 4700     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.151   |
# |    explained_variance | -0.2     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0293  |
# |    value_loss         | 0.785    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 4800     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.0786  |
# |    explained_variance | -0.545   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.0124   |
# |    value_loss         | 0.941    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 4900     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.0297  |
# |    explained_variance | -0.0102  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.00164 |
# |    value_loss         | 0.208    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 5000     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.0454  |
# |    explained_variance | -0.00378 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.000907 |
# |    value_loss         | 0.129    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 5100     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.0266  |
# |    explained_variance | -0.00127 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.00687 |
# |    value_loss         | 6.28     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 329      |
# |    iterations         | 5200     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.0396  |
# |    explained_variance | -0.451   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.0127   |
# |    value_loss         | 2.63     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 5300     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.0113  |
# |    explained_variance | 0.000163 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.00045  |
# |    value_loss         | 1.13     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 327      |
# |    iterations         | 5400     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.0454  |
# |    explained_variance | -0.0412  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.0751  |
# |    value_loss         | 47.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 326      |
# |    iterations         | 5500     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.057   |
# |    explained_variance | -0.576   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0186   |
# |    value_loss         | 2.9      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 325       |
# |    iterations         | 5600      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.0218   |
# |    explained_variance | -0.119    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -0.000176 |
# |    value_loss         | 0.272     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 5700     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.00516 |
# |    explained_variance | 0.000171 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.00114  |
# |    value_loss         | 4.01     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 5800     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.0329  |
# |    explained_variance | -0.0312  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.0149  |
# |    value_loss         | 11.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 323      |
# |    iterations         | 5900     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.00857 |
# |    explained_variance | 0.0368   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.00293  |
# |    value_loss         | 9.53     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 322      |
# |    iterations         | 6000     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.00805 |
# |    explained_variance | 0.1      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.00152  |
# |    value_loss         | 2.65     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 323      |
# |    iterations         | 6100     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.0156  |
# |    explained_variance | 0.00171  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0012  |
# |    value_loss         | 0.397    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 324       |
# |    iterations         | 6200      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.0156   |
# |    explained_variance | 0.00038   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -0.000779 |
# |    value_loss         | 0.679     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 326      |
# |    iterations         | 6300     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.021   |
# |    explained_variance | 0.0864   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.00233 |
# |    value_loss         | 1.59     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 327      |
# |    iterations         | 6400     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.0123  |
# |    explained_variance | 0.000619 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.00153  |
# |    value_loss         | 1.25     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 6500     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.0272  |
# |    explained_variance | 0.00479  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.000623 |
# |    value_loss         | 0.0553   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 329       |
# |    iterations         | 6600      |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.0198   |
# |    explained_variance | -0.0231   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -0.000937 |
# |    value_loss         | 0.225     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 6700     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.0107  |
# |    explained_variance | 0.233    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.000587 |
# |    value_loss         | 0.202    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 330       |
# |    iterations         | 6800      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.0126   |
# |    explained_variance | -0.000211 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | 0.00336   |
# |    value_loss         | 9.15      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 6900     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.0139  |
# |    explained_variance | 0.06     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.00166 |
# |    value_loss         | 1.71     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 7000     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.00627 |
# |    explained_variance | 0.0201   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.000686 |
# |    value_loss         | 0.855    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 7100      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.00583  |
# |    explained_variance | -0.000926 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0.000237 |
# |    value_loss         | 0.181     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 7200     |
# |    time_elapsed       | 108      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.00584 |
# |    explained_variance | 0.000137 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.00122  |
# |    value_loss         | 3.7      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 7300     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.00939 |
# |    explained_variance | -0.0167  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.00027  |
# |    value_loss         | 0.0531   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 7400     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.0132  |
# |    explained_variance | -0.158   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.000639 |
# |    value_loss         | 3.26     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 332       |
# |    iterations         | 7500      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -0.00236  |
# |    explained_variance | -0.0278   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | -0.000515 |
# |    value_loss         | 4.84      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 7600     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.00572 |
# |    explained_variance | -0.292   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.000464 |
# |    value_loss         | 0.482    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 332       |
# |    iterations         | 7700      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.00618  |
# |    explained_variance | -0.301    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -0.000969 |
# |    value_loss         | 1.11      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 7800     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.00582 |
# |    explained_variance | -0.15    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | -0.00115 |
# |    value_loss         | 3.04     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 7900      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -0.00221  |
# |    explained_variance | -0.00633  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | -4.26e-05 |
# |    value_loss         | 0.0774    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 8000      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -0.00192  |
# |    explained_variance | 0.0913    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -7.12e-05 |
# |    value_loss         | 0.147     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 8100      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -0.00183  |
# |    explained_variance | -0.0029   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | -0.000431 |
# |    value_loss         | 8.66      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 8200     |
# |    time_elapsed       | 123      |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.00463 |
# |    explained_variance | 0.351    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | 0.000427 |
# |    value_loss         | 2.44     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 330       |
# |    iterations         | 8300      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -0.00189  |
# |    explained_variance | -0.00184  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | -2.12e-05 |
# |    value_loss         | 0.869     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 8400     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.00453 |
# |    explained_variance | -0.0292  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | -0.00382 |
# |    value_loss         | 38.8     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 329      |
# |    iterations         | 8500     |
# |    time_elapsed       | 128      |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.00624 |
# |    explained_variance | 0.0173   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 0.000743 |
# |    value_loss         | 1.93     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 328       |
# |    iterations         | 8600      |
# |    time_elapsed       | 130       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -0.00704  |
# |    explained_variance | 0.0922    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -5.68e-05 |
# |    value_loss         | 0.0796    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 8700     |
# |    time_elapsed       | 132      |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -0.0129  |
# |    explained_variance | -0.0946  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | 0.00263  |
# |    value_loss         | 2.82     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 327       |
# |    iterations         | 8800      |
# |    time_elapsed       | 134       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -0.0139   |
# |    explained_variance | 0.00682   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -0.000221 |
# |    value_loss         | 1.03      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 327      |
# |    iterations         | 8900     |
# |    time_elapsed       | 136      |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -0.00906 |
# |    explained_variance | 0.000343 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | 0.00253  |
# |    value_loss         | 7.27     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 326      |
# |    iterations         | 9000     |
# |    time_elapsed       | 137      |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.00874 |
# |    explained_variance | -0.00459 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | 0.00107  |
# |    value_loss         | 1.43     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 327       |
# |    iterations         | 9100      |
# |    time_elapsed       | 139       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -0.00848  |
# |    explained_variance | -0.000623 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | 0.000513  |
# |    value_loss         | 0.352     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 328       |
# |    iterations         | 9200      |
# |    time_elapsed       | 140       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -0.00825  |
# |    explained_variance | -0.00497  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9199      |
# |    policy_loss        | -6.14e-05 |
# |    value_loss         | 0.479     |
# ...
# |    entropy_loss       | -0.00273  |
# |    explained_variance | -9.75     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 56999     |
# |    policy_loss        | -2.91e-07 |
# |    value_loss         | 1.34e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 57100    |
# |    time_elapsed       | 863      |
# |    total_timesteps    | 285500   |
# | train/                |          |
# |    entropy_loss       | -0.00276 |
# |    explained_variance | -1.91    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57099    |
# |    policy_loss        | 1.16e-08 |
# |    value_loss         | 2.97e-09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 330       |
# |    iterations         | 57200     |
# |    time_elapsed       | 864       |
# |    total_timesteps    | 286000    |
# | train/                |           |
# |    entropy_loss       | -0.00273  |
# |    explained_variance | -3.09     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 57199     |
# |    policy_loss        | -3.25e-08 |
# |    value_loss         | 1.64e-08  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 57300    |
# |    time_elapsed       | 865      |
# |    total_timesteps    | 286500   |
# | train/                |          |
# |    entropy_loss       | -0.00261 |
# |    explained_variance | -107     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57299    |
# |    policy_loss        | 4.22e-08 |
# |    value_loss         | 6.09e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 57400    |
# |    time_elapsed       | 866      |
# |    total_timesteps    | 287000   |
# | train/                |          |
# |    entropy_loss       | -0.00259 |
# |    explained_variance | -0.0525  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57399    |
# |    policy_loss        | 1.81e-08 |
# |    value_loss         | 5.12e-09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 57500     |
# |    time_elapsed       | 867       |
# |    total_timesteps    | 287500    |
# | train/                |           |
# |    entropy_loss       | -0.00262  |
# |    explained_variance | -1.13     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 57499     |
# |    policy_loss        | -1.21e-08 |
# |    value_loss         | 1.97e-09  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 57600    |
# |    time_elapsed       | 869      |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -0.00262 |
# |    explained_variance | -0.442   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57599    |
# |    policy_loss        | 2.59e-07 |
# |    value_loss         | 1.01e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 57700    |
# |    time_elapsed       | 870      |
# |    total_timesteps    | 288500   |
# | train/                |          |
# |    entropy_loss       | -0.0026  |
# |    explained_variance | -0.142   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57699    |
# |    policy_loss        | 1.13e-08 |
# |    value_loss         | 4.66e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 57800    |
# |    time_elapsed       | 871      |
# |    total_timesteps    | 289000   |
# | train/                |          |
# |    entropy_loss       | -0.00262 |
# |    explained_variance | 0.248    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57799    |
# |    policy_loss        | 6.2e-08  |
# |    value_loss         | 5.12e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 57900    |
# |    time_elapsed       | 873      |
# |    total_timesteps    | 289500   |
# | train/                |          |
# |    entropy_loss       | -0.00259 |
# |    explained_variance | -0.357   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57899    |
# |    policy_loss        | 2.32e-08 |
# |    value_loss         | 7.57e-09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 58000     |
# |    time_elapsed       | 874       |
# |    total_timesteps    | 290000    |
# | train/                |           |
# |    entropy_loss       | -0.0026   |
# |    explained_variance | -1.4e+04  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 57999     |
# |    policy_loss        | -3.56e-08 |
# |    value_loss         | 6.26e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 58100     |
# |    time_elapsed       | 875       |
# |    total_timesteps    | 290500    |
# | train/                |           |
# |    entropy_loss       | -0.00258  |
# |    explained_variance | -0.279    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 58099     |
# |    policy_loss        | -3.94e-07 |
# |    value_loss         | 2.47e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 58200    |
# |    time_elapsed       | 877      |
# |    total_timesteps    | 291000   |
# | train/                |          |
# |    entropy_loss       | -0.0026  |
# |    explained_variance | -2.74    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58199    |
# |    policy_loss        | 2.66e-08 |
# |    value_loss         | 1.3e-08  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 58300     |
# |    time_elapsed       | 878       |
# |    total_timesteps    | 291500    |
# | train/                |           |
# |    entropy_loss       | -0.00259  |
# |    explained_variance | -7.99     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 58299     |
# |    policy_loss        | -1.89e-08 |
# |    value_loss         | 9.63e-08  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 58400    |
# |    time_elapsed       | 880      |
# |    total_timesteps    | 292000   |
# | train/                |          |
# |    entropy_loss       | -0.00261 |
# |    explained_variance | -19.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58399    |
# |    policy_loss        | 1.18e-07 |
# |    value_loss         | 2.51e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 58500     |
# |    time_elapsed       | 881       |
# |    total_timesteps    | 292500    |
# | train/                |           |
# |    entropy_loss       | -0.00156  |
# |    explained_variance | -7.73e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 58499     |
# |    policy_loss        | 2.25e-08  |
# |    value_loss         | 1.2e-07   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 58600    |
# |    time_elapsed       | 883      |
# |    total_timesteps    | 293000   |
# | train/                |          |
# |    entropy_loss       | -0.00154 |
# |    explained_variance | 0.396    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58599    |
# |    policy_loss        | -2.8e-08 |
# |    value_loss         | 3.8e-08  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 58700    |
# |    time_elapsed       | 884      |
# |    total_timesteps    | 293500   |
# | train/                |          |
# |    entropy_loss       | -0.00156 |
# |    explained_variance | -1.62    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58699    |
# |    policy_loss        | 8.55e-09 |
# |    value_loss         | 3.93e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 58800    |
# |    time_elapsed       | 886      |
# |    total_timesteps    | 294000   |
# | train/                |          |
# |    entropy_loss       | -0.00155 |
# |    explained_variance | -29      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58799    |
# |    policy_loss        | -1.5e-09 |
# |    value_loss         | 1.63e-10 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 58900    |
# |    time_elapsed       | 887      |
# |    total_timesteps    | 294500   |
# | train/                |          |
# |    entropy_loss       | -0.00155 |
# |    explained_variance | -0.695   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58899    |
# |    policy_loss        | 8.54e-09 |
# |    value_loss         | 2.93e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 59000    |
# |    time_elapsed       | 889      |
# |    total_timesteps    | 295000   |
# | train/                |          |
# |    entropy_loss       | -0.00154 |
# |    explained_variance | -0.927   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58999    |
# |    policy_loss        | 3.54e-09 |
# |    value_loss         | 1.03e-09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 59100     |
# |    time_elapsed       | 891       |
# |    total_timesteps    | 295500    |
# | train/                |           |
# |    entropy_loss       | -0.00156  |
# |    explained_variance | -5.13     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59099     |
# |    policy_loss        | -8.43e-09 |
# |    value_loss         | 2.31e-08  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 59200    |
# |    time_elapsed       | 893      |
# |    total_timesteps    | 296000   |
# | train/                |          |
# |    entropy_loss       | -0.00157 |
# |    explained_variance | -3.3     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59199    |
# |    policy_loss        | 1.43e-08 |
# |    value_loss         | 3e-08    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 59300     |
# |    time_elapsed       | 894       |
# |    total_timesteps    | 296500    |
# | train/                |           |
# |    entropy_loss       | -0.00156  |
# |    explained_variance | -0.0205   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59299     |
# |    policy_loss        | -1.27e-07 |
# |    value_loss         | 7.62e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 59400    |
# |    time_elapsed       | 896      |
# |    total_timesteps    | 297000   |
# | train/                |          |
# |    entropy_loss       | -0.00156 |
# |    explained_variance | -167     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59399    |
# |    policy_loss        | 1.49e-08 |
# |    value_loss         | 1.07e-08 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 59500     |
# |    time_elapsed       | 898       |
# |    total_timesteps    | 297500    |
# | train/                |           |
# |    entropy_loss       | -0.003    |
# |    explained_variance | -4.44     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59499     |
# |    policy_loss        | -2.59e-09 |
# |    value_loss         | 3.29e-10  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 59600     |
# |    time_elapsed       | 900       |
# |    total_timesteps    | 298000    |
# | train/                |           |
# |    entropy_loss       | -0.00297  |
# |    explained_variance | -2.33e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59599     |
# |    policy_loss        | -3.33e-09 |
# |    value_loss         | 5.6e-10   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 330       |
# |    iterations         | 59700     |
# |    time_elapsed       | 901       |
# |    total_timesteps    | 298500    |
# | train/                |           |
# |    entropy_loss       | -0.003    |
# |    explained_variance | -213      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59699     |
# |    policy_loss        | -1.98e-09 |
# |    value_loss         | 9.18e-09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 330       |
# |    iterations         | 59800     |
# |    time_elapsed       | 903       |
# |    total_timesteps    | 299000    |
# | train/                |           |
# |    entropy_loss       | -0.00298  |
# |    explained_variance | -18.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59799     |
# |    policy_loss        | -2.88e-07 |
# |    value_loss         | 1.71e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 330       |
# |    iterations         | 59900     |
# |    time_elapsed       | 905       |
# |    total_timesteps    | 299500    |
# | train/                |           |
# |    entropy_loss       | -0.00302  |
# |    explained_variance | -0.124    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59899     |
# |    policy_loss        | -1.15e-06 |
# |    value_loss         | 1.17e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 60000    |
# |    time_elapsed       | 907      |
# |    total_timesteps    | 300000   |
# | train/                |          |
# |    entropy_loss       | -0.00302 |
# |    explained_variance | -158     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59999    |
# |    policy_loss        | -3e-07   |
# |    value_loss         | 1.99e-06 |
# ------------------------------------

# %%
model.save(f"models/{NAME}")

# %%
# Run env with model

eval_bounds = (0,38628)

profit_list = []

env = TradingEnv((train_x[eval_bounds[0]:eval_bounds[1]], train_y[eval_bounds[0]:eval_bounds[1]]))

state = env.reset()
while True: 
    action, *_ = model.predict(state)
    state, reward, done, info = env.step(action)
    print(info)
    if done: 
        print("info", info)
        break
        
# plt.figure(figsize=(15,6))
# plt.cla()
# env.render_all()
# plt.show()
# Out:
# {'index': 0, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 1, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 2, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 3, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 4, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 5, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 6, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 7, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 8, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 9, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 10, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 11, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 12, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 13, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 14, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 15, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 16, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 17, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 18, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 19, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 20, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 21, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 22, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 23, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 24, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 25, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 26, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 27, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 28, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 29, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 30, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 31, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 32, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 33, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 34, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 36, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 37, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 38, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 39, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 40, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 41, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 42, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 43, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 44, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 45, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 46, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 47, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 48, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 49, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 50, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 51, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 52, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 53, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 54, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 55, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 56, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 57, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 58, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 59, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 60, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 61, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 62, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 63, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 64, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 65, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 66, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 67, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 68, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 69, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 70, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 71, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 72, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 73, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 74, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 75, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 76, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 77, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 78, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 79, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 80, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 81, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 82, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 83, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 84, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 85, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 86, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 87, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 88, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 89, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 90, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 91, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 92, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 93, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 94, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 95, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 96, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 97, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 98, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 99, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 100, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 101, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 102, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 103, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 104, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 105, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 106, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 107, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 108, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 109, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 110, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 111, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 112, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 113, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 114, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 115, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 116, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 117, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 118, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 119, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 120, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 121, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 122, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 123, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 124, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 125, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 126, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 127, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 128, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 129, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 130, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 131, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 132, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 133, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 134, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 135, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 136, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 137, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 138, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 139, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 140, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 141, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 142, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 143, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 144, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 145, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 146, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 147, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 148, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 149, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 150, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 151, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 152, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 153, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 154, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 155, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 156, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 157, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 158, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 159, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 160, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 161, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 162, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 163, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 164, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 165, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 166, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 167, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 168, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 169, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 170, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 171, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 172, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 173, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 174, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 175, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 176, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 177, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 178, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 179, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 180, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 181, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 182, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 183, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 184, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 185, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 186, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 187, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 188, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 189, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 190, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 191, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 192, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 193, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 194, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 195, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 196, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 197, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 198, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 199, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 200, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 201, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 202, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 203, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 204, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 205, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 206, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 207, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 208, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 209, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 210, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 211, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 212, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 213, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 214, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 215, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 216, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 217, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 218, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 219, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 220, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 221, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 222, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 223, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 224, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 225, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 226, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 227, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 228, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 229, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 230, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 231, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 232, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 233, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 234, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 235, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 236, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 237, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 238, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 239, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 240, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 241, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 242, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 243, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 244, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 245, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 246, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 247, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 248, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 249, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 250, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 251, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 252, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 253, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 254, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 255, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 256, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 257, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 258, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 259, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 260, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 261, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 262, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 263, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 264, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 265, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 266, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 267, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 268, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 269, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 270, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 271, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 272, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 273, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 274, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 275, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 276, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 277, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 278, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 279, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 280, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 281, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 282, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 283, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 284, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 285, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 286, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 287, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 288, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 289, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 290, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 291, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 292, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 293, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 294, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 295, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 296, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 297, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 298, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 299, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 300, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 301, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 302, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 303, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 304, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 305, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 306, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 307, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 308, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 309, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 310, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 311, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 312, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 313, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 314, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 315, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 316, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 317, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 318, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 319, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 320, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 321, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 322, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 323, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 324, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 325, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 326, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 327, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 328, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 329, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 330, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 331, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 332, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 333, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 334, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 335, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 336, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 337, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 338, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 339, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 340, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 341, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 342, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 343, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 344, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 345, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 346, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 347, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 348, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 349, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 350, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 351, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 352, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 353, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 354, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 355, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 356, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 357, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 358, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 359, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 360, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 361, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 362, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 363, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 364, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 365, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 366, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 367, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 368, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 369, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 370, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 371, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 372, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 373, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 374, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 375, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 376, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 377, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 378, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 379, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 380, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 381, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 382, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 383, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 384, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 385, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 386, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 387, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 388, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 389, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 390, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 391, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 392, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 393, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 394, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 395, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 396, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 397, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 398, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 399, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 400, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 401, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 402, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 403, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 404, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 405, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 406, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 407, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 408, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 409, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 410, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 411, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 412, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 413, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 414, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 415, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 416, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 417, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 418, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 419, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 420, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 421, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 422, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 423, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 424, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 425, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 426, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 427, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 428, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 429, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 430, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 431, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 432, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 433, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 434, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 435, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 436, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 437, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 438, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 439, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 440, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 441, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 442, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 443, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 444, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 445, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 446, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 447, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 448, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 449, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 450, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 451, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 452, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 453, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 454, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 455, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 456, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 457, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 458, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 459, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 460, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 461, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 462, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 463, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 464, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 465, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 466, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 467, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 468, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 469, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 470, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 471, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 472, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 473, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 474, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 475, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 476, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 477, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 478, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 479, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 480, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 481, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 482, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 483, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 484, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 485, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 486, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 487, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 488, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 489, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 490, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 491, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 492, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 493, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 494, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 495, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 496, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 497, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 498, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 499, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 500, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 501, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 502, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 503, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 504, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 505, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 506, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 507, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 508, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 509, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 510, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 511, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 512, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 513, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 514, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 515, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 516, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 517, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 518, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 519, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 520, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 521, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 522, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 523, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 524, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 525, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 526, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 527, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 528, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 529, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 530, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 531, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 532, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 533, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 534, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 535, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 536, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 537, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 538, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 539, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 540, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 541, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 542, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 543, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 544, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 545, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 546, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 547, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 548, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 549, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 550, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 551, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 552, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 553, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 554, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 555, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 556, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 557, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 558, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 559, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 560, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 561, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 562, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 563, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 564, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 565, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 566, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 567, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 568, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 569, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 570, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 571, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 572, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 573, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 574, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 575, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 576, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 577, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 578, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 579, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 580, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 581, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 582, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 583, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 584, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 585, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 586, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 587, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 588, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 589, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 590, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 591, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 592, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 593, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 594, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 595, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 596, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 597, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 598, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 599, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 600, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 601, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 602, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 603, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 604, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 605, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 606, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 607, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 608, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 609, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 610, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 611, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 612, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 613, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 614, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 615, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 616, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 617, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 618, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 619, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 620, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 621, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 622, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 623, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 624, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 625, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 626, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 627, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 628, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 629, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 630, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 631, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 632, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 633, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 634, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 635, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 636, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 637, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 638, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 639, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 640, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# ...
# {'index': 35419, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35420, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35421, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35422, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35423, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35424, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35425, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35426, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35427, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35428, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35429, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35430, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35431, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35432, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35433, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35434, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35435, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35436, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35437, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35438, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35439, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35440, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35441, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35442, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35443, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35444, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35445, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35446, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35447, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35448, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35449, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35450, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35451, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35452, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35453, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35454, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35455, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35456, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35457, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35458, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35459, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35460, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35461, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35462, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35463, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35464, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35465, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35466, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35467, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35468, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35469, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35470, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35471, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35472, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35473, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35474, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35475, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35476, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35477, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35478, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35479, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35480, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35481, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35482, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35483, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35484, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35485, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35486, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35487, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35488, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35489, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35490, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35491, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35492, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35493, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35494, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35495, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35496, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35497, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35498, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35499, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35500, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35501, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35502, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35503, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35504, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35505, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35506, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35507, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35508, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35509, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35510, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35511, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35512, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35513, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35514, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35515, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35516, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35517, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35518, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35519, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35520, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35521, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35522, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35523, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35524, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35525, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35526, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35527, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35528, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35529, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35530, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35531, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35532, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35533, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35534, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35535, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35536, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35537, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35538, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35539, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35540, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35541, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35542, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35543, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35544, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35545, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35546, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35547, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35548, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35549, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35550, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35551, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35552, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35553, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35554, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35555, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35556, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35557, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35558, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35559, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35560, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35561, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35562, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35563, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35564, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35565, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35566, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35567, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35568, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35569, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35570, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35571, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35572, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35573, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35574, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35575, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35576, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35577, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35578, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35579, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35580, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35581, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35582, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35583, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35584, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35585, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35586, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35587, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35588, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35589, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35590, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35591, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35592, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35593, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35594, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35595, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35596, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35597, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35598, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35599, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35600, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35601, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35602, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35603, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35604, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35605, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35606, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35607, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35608, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35609, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35610, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35611, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35612, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35613, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35614, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35615, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35616, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35617, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35618, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35619, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35620, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35621, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35622, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35623, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# {'index': 35624, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}
# info {'index': 35624, 'action': 'SELL', 'profit': 0, 'reward': 0.0, 'score': 0.0}

# %%
plt.plot(list(range(len(profit_list))), np.array(profit_list)+10000)
plt.plot(list(range(len(profit_list))), data["close"].tolist()[eval_bounds[0]:eval_bounds[1]])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 plt.plot(list(range(len(profit_list))), np.array(profit_list)+10000)
#       2 plt.plot(list(range(len(profit_list))), data["close"].tolist()[eval_bounds[0]:eval_bounds[1]])
#
# NameError: name 'profit_list' is not defined
